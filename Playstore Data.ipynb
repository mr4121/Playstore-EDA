# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df1=pd.read_csv('/Users/mohit-raj/Desktop/Assignments/Playstore Data – EDA/Google Playstore Data.csv')
df1.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                Coloring book moana  ART_AND_DESIGN    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df1.shape
# Out:
# (10841, 15)

# %%
df=df1
df.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                Coloring book moana  ART_AND_DESIGN    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 15)

# %%
#we can see that the dataset is not prepared well at all, there are 2 Unnamed columns. Let's drop them
df.drop(['Unnamed: 13', 'Unnamed: 14'], axis=1, inplace=True)
df.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                Coloring book moana  ART_AND_DESIGN    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   object
#  3   Reviews         10840 non-null  object
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10839 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10837 non-null  object
# dtypes: object(13)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             1
# Rating            1475
# Reviews              1
# Size                 1
# Installs             1
# Type                 2
# Price                1
# Content Rating       2
# Genres               1
# Last Updated         1
# Current Ver          9
# Android Ver          4
# dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS    4.2
# 236                                                Box      BUSINESS    4.2
# 239                                 Google My Business      BUSINESS    4.4
# 256                                ZOOM Cloud Meetings      BUSINESS    4.4
# 261                          join.me - Simple Meetings      BUSINESS      4
# ...                                                ...           ...    ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY    4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY    4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY    4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL    4.3
# 10768                                             AAFP       MEDICAL    3.8
#
# ...

# %% [markdown]
# ###### There are 483 duplicate values. Let's crosscheck and drop them

# %%
df[df['Reviews'] == '80805']
# Out:
#                               App  Category Rating Reviews  \
# 222  Quick PDF Scanner + OCR FREE  BUSINESS    4.2   80805
# 229  Quick PDF Scanner + OCR FREE  BUSINESS    4.2   80805
#
#                    Size    Installs  Type Price Content Rating    Genres  \
# 222  Varies with device  5,000,000+  Free     0       Everyone  Business
# 229  Varies with device  5,000,000+  Free     0       Everyone  Business
#
#           Last Updated         Current Ver   Android Ver
# 222  February 26, 2018  Varies with device  4.0.3 and up
# 229  February 26, 2018  Varies with device  4.0.3 and up

# %%
#we can see that there are duplicated values. Let's drop them
df.drop_duplicates(inplace=True)

# %%
#just to crosscheck
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
#now, let's check null values
df.isnull().sum()
# Out:
# App                  0
# Category             1
# Rating            1466
# Reviews              1
# Size                 1
# Installs             1
# Type                 2
# Price                1
# Content Rating       2
# Genres               1
# Last Updated         1
# Current Ver          9
# Android Ver          4
# dtype: int64

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION', nan,
#        'Edit & Share', 'sms', '1.9'], dtype=object)

# %%
df['Category'].value_counts()
# Out:
# FAMILY                 1943
# GAME                   1121
# TOOLS                   843
# BUSINESS                426
# MEDICAL                 408
# PRODUCTIVITY            407
# PERSONALIZATION         388
# LIFESTYLE               373
# COMMUNICATION           366
# FINANCE                 360
# SPORTS                  351
# PHOTOGRAPHY             322
# HEALTH_AND_FITNESS      306
# SOCIAL                  279
# NEWS_AND_MAGAZINES      264
# TRAVEL_AND_LOCAL        237
# BOOKS_AND_REFERENCE     230
# SHOPPING                224
# DATING                  196
# VIDEO_PLAYERS           174
# MAPS_AND_NAVIGATION     137
# EDUCATION               130
# FOOD_AND_DRINK          124
# ENTERTAINMENT           111
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# HOUSE_AND_HOME           80
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
df[df['Category'] == '1.9']
# Out:
#                                            App Category Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9     19    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
## We can see that there is 1 entry which hasn't been filled correctly. All the data is jumbled up,
##i.e. Rating seems to be in Category, Size in Reviews, Installs in Size. etc. We can drop this altogether.
df = df[df['Category'] != '1.9']

# %%
df[df['Category'].isna()]
# Out:
#           App Category Rating Reviews Size Installs Type Price Content Rating  \
# 8532  #ERROR!      NaN    NaN     NaN  NaN      NaN  NaN   NaN            NaN
#
#      Genres Last Updated Current Ver Android Ver
# 8532    NaN          NaN         NaN         NaN

# %%
#it seems like a junk. let's drop this
df = df.dropna(subset=['Category'])

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# Just by dropping the above na row, we got rid of a lot of nan values in the dataframe

# %%
#Let's check Type column
df['Type'].unique()
# Out:
# array(['Free', 'Paid', '10,000,000+', 'Varies with device', nan],
#       dtype=object)

# %%
df[df['Type']=='10,000,000+']
# Out:
#                     App      Category    Rating Reviews   Size  \
# 8631  PDF Reader - Scan  Edit & Share  BUSINESS     4.3  54520
#
#                 Installs         Type Price Content Rating    Genres  \
# 8631  Varies with device  10,000,000+  Free              0  Everyone
#
#      Last Updated    Current Ver Android Ver
# 8631     Business  July 30, 2018      3.12.4

# %%
#Let's drop the above row
df = df[df['Type'] != '10,000,000+']

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid', 'Varies with device', nan], dtype=object)

# %%
df['Type'].isnull().sum()
# Out:
# 1

# %%
df[df['Type'].isna()]
# Out:
#                             App Category Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY    NaN       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
#it has NaN values in 2 columns, so let's drop this
df=df.dropna(subset=['Type'])

# %%
df['Type'].isna().sum()
# Out:
# 0

# %%
#Now, let's check the dataframe again
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1464
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
#let's check the Current Ver and Android Ver
df[df['Current Ver'].isnull()]
# Out:
#                                    App             Category Rating Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN    3.2      55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO    4.1   20145
# 6322            Virtual DJ Sound Mixer                TOOLS    4.2    4010
# 6803                         BT Master               FAMILY    NaN       0
# 7333                       Dots puzzle               FAMILY      4     179
# 7407                   Calculate My IQ               FAMILY    NaN      44
# 7730                            UFO-CQ                TOOLS    NaN       1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE    NaN       8
#
#        Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.7M      5,000+  Free      0       Everyone       Art & Design
# 1553    11k  1,000,000+  Free      0       Everyone   Libraries & Demo
# 6322   8.7M    500,000+  Free      0       Everyone              Tools
# ...

# %%
df['Current Ver'].value_counts()
# Out:
# Varies with device    1300
# 1                      834
# 1.1                    272
# 1.2                    184
# 2                      163
#                       ...
# 4.2.2254.129147          1
# 3.1.6.9                  1
# 8.3                      1
# 5.2.5                    1
# 2.0.148.0                1
# Name: Current Ver, Length: 2782, dtype: int64

# %%
df['Android Ver'].value_counts()
# Out:
# 4.1 and up            2378
# 4.0.3 and up          1450
# 4.0 and up            1337
# Varies with device    1219
# 4.4 and up             894
# 2.3 and up             643
# 5.0 and up             546
# 4.2 and up             387
# 2.3.3 and up           279
# 2.2 and up             239
# 3.0 and up             237
# 4.3 and up             235
# 2.1 and up             133
# 1.6 and up             116
# 6.0 and up              58
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              22
# 1.5 and up              20
# 4.4W and up             11
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# August 16, 2017          1
# 2.2 - 7.1.1              1
# 7.0 - 7.1.1              1
# 5.0 - 6.0                1
# 4.1 - 7.1.1              1
# 5.0 - 7.1.1              1
# ...

# %%
df[df['Android Ver'] == 'August 16, 2017']
# Out:
#                        App Category Rating        Reviews Size Installs  \
# 8902  DU Privacy-hide apps      sms   file  VIDEO_PLAYERS  4.4    21762
#
#                     Type       Price Content Rating Genres Last Updated  \
# 8902  Varies with device  1,000,000+           Free      0     Everyone
#
#                   Current Ver      Android Ver
# 8902  Video Players & Editors  August 16, 2017

# %%
#There seems to be some problem with the entry, let's drop this
df= df[df['Android Ver'] != 'August 16, 2017']

# %%
df['Android Ver'].value_counts()
# Out:
# 4.1 and up            2378
# 4.0.3 and up          1450
# 4.0 and up            1337
# Varies with device    1219
# 4.4 and up             894
# 2.3 and up             643
# 5.0 and up             546
# 4.2 and up             387
# 2.3.3 and up           279
# 2.2 and up             239
# 3.0 and up             237
# 4.3 and up             235
# 2.1 and up             133
# 1.6 and up             116
# 6.0 and up              58
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              22
# 1.5 and up              20
# 4.4W and up             11
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10353 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10353 non-null  object
#  1   Category        10353 non-null  object
#  2   Rating          8889 non-null   object
#  3   Reviews         10353 non-null  object
#  4   Size            10353 non-null  object
#  5   Installs        10353 non-null  object
#  6   Type            10353 non-null  object
#  7   Price           10353 non-null  object
#  8   Content Rating  10353 non-null  object
#  9   Genres          10353 non-null  object
#  10  Last Updated    10353 non-null  object
#  11  Current Ver     10345 non-null  object
#  12  Android Ver     10351 non-null  object
# dtypes: object(13)
# memory usage: 1.1+ MB

# %%
df['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
#let's convert everything into 'k' and not have k at the end. Also replace 'Varies with device' with nan
df['Size'] = df['Size'].str.replace('M', '000')
df['Size'] = df['Size'].str.replace('k', '')
df['Size'] = df['Size'].replace('Varies with device', np.nan)

# %%
df['Size'].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', nan, '9.4000', '15000', '10000', '1.2000', '26000',
#        '8.0000', '7.9000', '56000', '57000', '35000', '54000', '201',
#        '3.6000', '5.7000', '8.6000', '2.4000', '27000', '2.5000', '16000',
#        '3.4000', '8.9000', '3.9000', '2.9000', '38000', '32000', '5.4000',
#        '18000', '1.1000', '2.2000', '4.5000', '9.8000', '52000', '9.0000',
#        '6.7000', '30000', '2.6000', '7.1000', '3.7000', '22000', '7.4000',
#        '6.4000', '3.2000', '8.2000', '9.9000', '4.9000', '9.5000',
#        '5.0000', '5.9000', '13000', '73000', '6.8000', '3.5000', '4.0000',
#        '2.3000', '7.2000', '2.1000', '42000', '7.3000', '9.1000', '55000',
# ...

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+'], dtype=object)

# %%
df['Installs'] = df['Installs'].str.replace('+','')
df['Installs'] = df['Installs'].str.replace(',','')
df['Installs'].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10353 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10353 non-null  object
#  1   Category        10353 non-null  object
#  2   Rating          8889 non-null   object
#  3   Reviews         10353 non-null  object
#  4   Size            8830 non-null   object
#  5   Installs        10353 non-null  object
#  6   Type            10353 non-null  object
#  7   Price           10353 non-null  object
#  8   Content Rating  10353 non-null  object
#  9   Genres          10353 non-null  object
#  10  Last Updated    10353 non-null  object
#  11  Current Ver     10345 non-null  object
#  12  Android Ver     10351 non-null  object
# dtypes: object(13)
# memory usage: 1.1+ MB

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df['Price']= df['Price'].str.replace('$','')
df['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
df['Genres'].unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
# ...

# %%
df['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
df['Last Updated'] = pd.to_datetime(df['Last Updated'])
df['Last Updated_Day'] = df['Last Updated'].dt.day
df['Last Updated_Month'] = df['Last Updated'].dt.month
df['Last Updated_Year'] = df['Last Updated'].dt.year

# %%
df.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                Coloring book moana  ART_AND_DESIGN    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
#
#   Reviews    Size  Installs  Type Price Content Rating  \
# 0     159   19000     10000  Free     0       Everyone
# 1     967   14000    500000  Free     0       Everyone
# 2   87510  8.7000   5000000  Free     0       Everyone
# 3  215644   25000  50000000  Free     0           Teen
# 4     967  2.8000    100000  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10353 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   App                 10353 non-null  object
#  1   Category            10353 non-null  object
#  2   Rating              8889 non-null   object
#  3   Reviews             10353 non-null  object
#  4   Size                8830 non-null   object
#  5   Installs            10353 non-null  object
#  6   Type                10353 non-null  object
#  7   Price               10353 non-null  object
#  8   Content Rating      10353 non-null  object
#  9   Genres              10353 non-null  object
#  10  Last Updated        10353 non-null  datetime64[ns]
#  11  Current Ver         10345 non-null  object
#  12  Android Ver         10351 non-null  object
#  13  Last Updated_Day    10353 non-null  int64
#  14  Last Updated_Month  10353 non-null  int64
# ...

# %%
df['Current Ver'].unique()
# Out:
# array(['1.0.0', '2.0.0', '1.2.4', ..., '1.0.612928', '0.3.4', '2.0.148.0'],
#       dtype=object)

# %%
df['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
#Now let's convert the datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10353 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   App                 10353 non-null  object
#  1   Category            10353 non-null  object
#  2   Rating              8889 non-null   object
#  3   Reviews             10353 non-null  object
#  4   Size                8830 non-null   object
#  5   Installs            10353 non-null  object
#  6   Type                10353 non-null  object
#  7   Price               10353 non-null  object
#  8   Content Rating      10353 non-null  object
#  9   Genres              10353 non-null  object
#  10  Last Updated        10353 non-null  datetime64[ns]
#  11  Current Ver         10345 non-null  object
#  12  Android Ver         10351 non-null  object
#  13  Last Updated_Day    10353 non-null  int64
#  14  Last Updated_Month  10353 non-null  int64
# ...

# %%
df['Rating'] = df['Rating'].astype(float)
df['Reviews'] = df['Reviews'].astype(float)
df['Size'] = df['Size'].astype(float)
df['Installs'] = df['Installs'].astype(int)
df['Price'] = df['Price'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10353 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   App                 10353 non-null  object
#  1   Category            10353 non-null  object
#  2   Rating              8889 non-null   float64
#  3   Reviews             10353 non-null  float64
#  4   Size                8830 non-null   float64
#  5   Installs            10353 non-null  int64
#  6   Type                10353 non-null  object
#  7   Price               10353 non-null  float64
#  8   Content Rating      10353 non-null  object
#  9   Genres              10353 non-null  object
#  10  Last Updated        10353 non-null  datetime64[ns]
#  11  Current Ver         10345 non-null  object
#  12  Android Ver         10351 non-null  object
#  13  Last Updated_Day    10353 non-null  int64
#  14  Last Updated_Month  10353 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# App                      0
# Category                 0
# Rating                1464
# Reviews                  0
# Size                  1523
# Installs                 0
# Type                     0
# Price                    0
# Content Rating           0
# Genres                   0
# Last Updated             0
# Current Ver              8
# Android Ver              2
# Last Updated_Day         0
# Last Updated_Month       0
# Last Updated_Year        0
# dtype: int64

# %%
#let's save the cleaned data
df.to_csv('/Users/mohit-raj/Desktop/Assignments/Playstore Data – EDA/Google Playstore Cleaned.csv')

# %%
df['Rating'].isnull().sum()
# Out:
# 1464

# %%
df[df['Rating'].isnull()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#        Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %%
df['Rating'].describe()
# Out:
# count    8889.000000
# mean        4.187805
# std         0.522448
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %%
#let's replace the na values with mean
df['Rating'].mean()
# Out:
# 4.187805152435602

# %%
df['Rating'].fillna(df['Rating'].mean(),inplace=True)

# %%
df['Rating'].isnull().sum()
# Out:
# 0

# %%
df['Size'].isnull().sum()
# Out:
# 1523

# %%
df['Size'].describe()
# Out:
# count      8830.000000
# mean      19321.827248
# std       23999.153305
# min           1.000000
# 25%           5.500000
# 50%       13000.000000
# 75%       29000.000000
# max      100000.000000
# Name: Size, dtype: float64

# %%
df['Size'].value_counts()
# Out:
# 11000.0    188
# 12000.0    186
# 13000.0    186
# 14000.0    182
# 15000.0    174
#           ...
# 430.0        1
# 429.0        1
# 200.0        1
# 460.0        1
# 619.0        1
# Name: Size, Length: 459, dtype: int64

# %%
#let's fill the nas with mean again
df['Size'].fillna(df['Size'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# App                   0
# Category              0
# Rating                0
# Reviews               0
# Size                  0
# Installs              0
# Type                  0
# Price                 0
# Content Rating        0
# Genres                0
# Last Updated          0
# Current Ver           8
# Android Ver           2
# Last Updated_Day      0
# Last Updated_Month    0
# Last Updated_Year     0
# dtype: int64

# %%
df[df['Current Ver'].isnull()]
# Out:
#                                    App             Category    Rating  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN  3.200000
# 1553              Market Update Helper   LIBRARIES_AND_DEMO  4.100000
# 6322            Virtual DJ Sound Mixer                TOOLS  4.200000
# 6803                         BT Master               FAMILY  4.187805
# 7333                       Dots puzzle               FAMILY  4.000000
# 7407                   Calculate My IQ               FAMILY  4.187805
# 7730                            UFO-CQ                TOOLS  4.187805
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE  4.187805
#
#        Reviews     Size  Installs  Type  Price Content Rating  \
# 15        55.0      2.7      5000  Free   0.00       Everyone
# 1553   20145.0     11.0   1000000  Free   0.00       Everyone
# 6322    4010.0      8.7    500000  Free   0.00       Everyone
# 6803       0.0    222.0       100  Free   0.00       Everyone
# ...

# %%
df['Current Ver'].describe()
# Out:
# count                  10345
# unique                  2781
# top       Varies with device
# freq                    1300
# Name: Current Ver, dtype: object

# %%
df['Current Ver'] = df['Current Ver'].replace('Varies with device', np.nan)

# %%
df['Current Ver'].value_counts()
# Out:
# 1                  834
# 1.1                272
# 1.2                184
# 2                  163
# 1.3                142
#                   ...
# 4.2.2254.129147      1
# 3.1.6.9              1
# 8.3                  1
# 5.2.5                1
# 2.0.148.0            1
# Name: Current Ver, Length: 2780, dtype: int64

# %%
df['Current Ver'].describe()
# Out:
# count     9045
# unique    2780
# top          1
# freq       834
# Name: Current Ver, dtype: object

# %%
df['Android Ver'] = df['Android Ver'].fillna(df['Android Ver'].mode()[0])

# %%
df.isnull().sum()
# Out:
# App                      0
# Category                 0
# Rating                   0
# Reviews                  0
# Size                     0
# Installs                 0
# Type                     0
# Price                    0
# Content Rating           0
# Genres                   0
# Last Updated             0
# Current Ver           1308
# Android Ver              0
# Last Updated_Day         0
# Last Updated_Month       0
# Last Updated_Year        0
# dtype: int64

# %%
df['Current Ver'] =df['Current Ver'].fillna(df['Current Ver'].mode()[0])

# %%
df.isnull().sum()
# Out:
# App                   0
# Category              0
# Rating                0
# Reviews               0
# Size                  0
# Installs              0
# Type                  0
# Price                 0
# Content Rating        0
# Genres                0
# Last Updated          0
# Current Ver           0
# Android Ver           0
# Last Updated_Day      0
# Last Updated_Month    0
# Last Updated_Year     0
# dtype: int64

# %% [markdown]
# ##### Now that we have cleaned the data, let's move to
# ### EDA

# %%
numerical_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

print('We have {} numerical features: {}'.format(len(numerical_features),numerical_features))
print('\nWe have {} categorical features: {}'.format(len(categorical_features),categorical_features))
# Out:
# We have 9 numerical features: ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Last Updated', 'Last Updated_Day', 'Last Updated_Month', 'Last Updated_Year']
#
# We have 7 categorical features: ['App', 'Category', 'Type', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver']

# %%
## Proportion of count data on numerical columns
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numerical_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[numerical_features[i]],shade=True, color='r')
    plt.xlabel(numerical_features[i])
    plt.tight_layout()

# %% [markdown]
# #### We can see that Rating, Last Updated, and Last Updated_Year are left skewed, while Density, Installs and Price are right skewed

# %%
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'Type', 'Content Rating']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df[category[i]],palette="Set2")
    plt.xlabel(category[i],fontsize=14, fontweight='bold')
    plt.ylabel("Count", fontsize=14, fontweight='bold')
    plt.xticks(rotation=45, fontsize=13)
    plt.yticks(fontsize=13)
    plt.tight_layout()

# %%
df['Category'].value_counts().plot.pie(
    autopct='%1.1f%%',   # show percentages
    figsize=(15, 16),      # size of the chart
    colormap='Set2'      # nice color palette
)
plt.ylabel("")  # remove default y-label
plt.title("Category Distribution", fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# ### Observations
#
# 1. Around 37% of the apps in playstore fall under category of family, games & tools
# 2. Apps falling under category Beatuty, comics, arts and weather are very less

# %%
plt.figure(figsize=(15,6))
sns.barplot(
    x=df['Category'].value_counts().index[:10],
    y=df['Category'].value_counts().values[:10],
    palette="hls"
)
plt.title("Top 10 App Categories", fontsize=16, fontweight='bold')
plt.xticks(rotation=45)
plt.ylabel("Count")
plt.show()

# %%
df_cat_installs = df.groupby(['Category'])['Installs'].sum().sort_values(ascending = False).reset_index()
df_cat_installs.Installs = df_cat_installs.Installs/1000000000# converting into billions
df2 = df_cat_installs.head(10)
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'Installs' , y = 'Category' , data = df2 )
ax.set_xlabel('No. of Installations in Billions')
ax.set_ylabel('')
ax.set_title("Most Popular Categories in Play Store", size = 20)
# Out:
# Text(0.5, 1.0, 'Most Popular Categories in Play Store')

# %%
dfa = df.groupby(['Category' ,'App'])['Installs'].sum().reset_index()
dfa = dfa.sort_values('Installs', ascending = False)
apps = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL' ]
sns.set_context("poster")
sns.set_style("darkgrid")

plt.figure(figsize=(40,30))

for i,app in enumerate(apps):
    df2 = dfa[dfa.Category == app]
    df3 = df2.head(5)
    plt.subplot(4,2,i+1)
    sns.barplot(data= df3,x= 'Installs' ,y='App' )
    plt.xlabel('Installation in Millions')
    plt.ylabel('')
    plt.title(app,size = 20)
    
plt.tight_layout()
plt.subplots_adjust(hspace= .3)
plt.show()

# %% [markdown]
# ### Insights
# - Most popular game is Subway Surfers.
# - Most popular communication app is Hangouts.
# - Most popular productivity app is Google Drive.
# - Most popular social app is Instagram.

# %%
rating = df.groupby(['Category','Installs', 'App'])['Rating'].sum().sort_values(ascending = False).reset_index()

toprating_apps = rating[rating.Rating == 5.0]
print("Number of 5 rated apps",toprating_apps.shape[0])
toprating_apps.head(1)
# Out:
# Number of 5 rated apps 271
#     Category  Installs                    App  Rating
# 461    TOOLS        50  CR Tracker for Chests     5.0

# %% [markdown]
# ### Result
# - There are 271 five rated apps on Google Play store
# - Top most is 'CT Brain Interpretation' from 'Family' Category
